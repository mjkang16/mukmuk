# %%
import tensorflow as tf
from Strategy import RL

# %%
case_num = 3
# 1 : epsilon , 2 : softmax , 3 : sparsemax , 4 : sparse+eps
Exp_list = ['sparse+eps', 'epsilon', 'softmax']
Double_list = [True, True, False]
Dueling_list = [True, True, True]
Prioritized_list = [True, True, True]
action_res_list = [16, 16]

with tf.Session() as sess :
    #for i in range(case_num):    
    CartPole = RL(sess, dis = 0.99, REPLAY_MEMORY = 10000, batch_size = 32, max_episodes = 1000,
                      training_step = 1, copy_step = 2, action_res = 64,
                      layer_size = 128, learning_rate = 0.0001,
                      alpha = 0.6, beta_init = 0.4, eps = 0.01, eps_div = 2,
                      ending_cond_epis = 100, ending_cond_reward = 950, reward_p = 100, reward_n = -100,
                      Game = 'InvertedPendulum-v1')
    
    for i in range(case_num):
        tf.
        CartPole.run_RL(case_n = i+1, Exp = Exp_list[i], seed_n = 0,
                       Double = Double_list[i], Dueling = Dueling_list[i], Prioritized = Prioritized_list[i])
# Out:
# [2018-02-21 14:30:19,117] Making new env: InvertedPendulum-v1
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2018-02-21 14:30:20,141] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# CASE 1
#   Exp : sparse+eps
#   Strategy : Double : True, Dueling : True, Prioritized : True
# 1           5.0
# 2           4.5
# 3           5.0
# 4           4.5
# 5           4.2
# 6           4.0
# 7           4.0
# 8           5.125
# 9           5.11111111111
# 10           5.4
# 11           5.18181818182
# 12           5.0
# 13           5.15384615385
# 14           5.07142857143
# 15           5.13333333333
# 16           5.1875
# 17           5.23529411765
# 18           5.11111111111
# 19           5.31578947368
# 20           5.4
# 21           5.52380952381
# 22           5.40909090909
# 23           5.39130434783
# 24           5.33333333333
# 25           5.24
# 26           5.15384615385
# 27           5.18518518519
# 28           5.10714285714
# 29           5.44827586207
# 30           5.4
# 31           5.35483870968
# 32           5.28125
# 33           5.21212121212
# 34           5.26470588235
# 35           5.2
# 36           5.13888888889
# 37           5.13513513514
# 38           5.13157894737
# 39           5.15384615385
# 40           5.125
# 41           5.07317073171
# 42           5.02380952381
# 43           4.97674418605
# 44           4.97727272727
# 45           4.91111111111
# 46           4.91304347826
# 47           4.87234042553
# 48           4.9375
# 49           4.9387755102
# 50           4.9
# 51           4.86274509804
# 52           4.86538461538
# 53           4.84905660377
# 54           4.83333333333
# 55           4.8
# 56           4.76785714286
# 57           4.73684210526
# 58           4.70689655172
# 59           4.67796610169
# 60           4.65
# 61           4.67213114754
# 62           4.64516129032
# 63           4.61904761905
# 64           4.59375
# 65           4.58461538462
# 66           4.56060606061
# 67           4.5671641791
# 68           4.54411764706
# 69           4.52173913043
# 70           4.5
# 71           4.49295774648
# 72           4.47222222222
# 73           4.45205479452
# 74           4.43243243243
# 75           4.42666666667
# 76           4.42105263158
# 77           4.4025974026
# 78           4.38461538462
# 79           4.37974683544
# 80           4.3625
# 81           4.35802469136
# 82           4.34146341463
# 83           4.32530120482
# 84           4.30952380952
# 85           4.31764705882
# 86           4.31395348837
# 87           4.29885057471
# 88           4.28409090909
# 89           4.26966292135
# 90           4.27777777778
# 91           4.27472527473
# 92           4.28260869565
# 93           4.2688172043
# 94           4.26595744681
# 95           4.25263157895
# 96           4.23958333333
# 97           4.22680412371
# 98           4.22448979592
# 99           4.22222222222
# 100           4.23
# 101           4.21
# 102           4.2
# 103           4.17
# 104           4.21
# 105           4.21
# 106           4.22
# 107           4.21
# 108           4.12
# 109           4.1
# 110           4.05
# 111           4.05
# 112           4.06
# 113           4.03
# 114           4.02
# 115           3.99
# 116           3.97
# 117           3.94
# 118           3.95
# 119           3.9
# 120           3.86
# 121           3.81
# 122           3.81
# 123           3.79
# 124           3.78
# 125           3.78
# 126           3.79
# 127           3.77
# 128           3.77
# 129           3.65
# 130           3.64
# 131           3.64
# 132           3.65
# 133           3.65
# 134           3.62
# 135           3.62
# 136           3.62
# 137           3.6
# 138           3.58
# 139           3.55
# 140           3.54
# 141           3.58
# 142           3.59
# 143           3.59
# 144           3.57
# 145           3.6
# 146           3.58
# 147           3.58
# 148           3.56
# 149           3.54
# 150           3.54
# 151           3.54
# 152           3.52
# 153           3.51
# 154           3.52
# 155           3.54
# 156           3.54
# 157           3.55
# 158           3.59
# 159           3.59
# 160           3.59
# 161           3.56
# 162           3.58
# 163           3.58
# 164           3.59
# 165           3.58
# 166           3.58
# 167           3.56
# 168           3.56
# 169           3.57
# 170           3.57
# 171           3.57
# 172           3.57
# 173           3.59
# 174           3.61
# 175           3.61
# 176           3.65
# 177           3.65
# 178           3.65
# 179           3.65
# 180           3.67
# 181           3.66
# 182           3.67
# 183           3.67
# 184           3.67
# 185           3.65
# 186           3.64
# 187           3.63
# 188           3.63
# 189           3.63
# 190           3.61
# 191           3.62
# 192           3.6
# 193           3.6
# 194           3.6
# 195           3.6
# 196           3.6
# 197           3.61
# 198           3.6
# 199           3.59
# 200           3.58
# 201           3.59
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ae323242d346> in <module>()
#      18     for i in range(case_num):
#      19         CartPole.run_RL(case_n = i+1, Exp = Exp_list[i], seed_n = 0,
# ---> 20                        Double = Double_list[i], Dueling = Dueling_list[i], Prioritized = Prioritized_list[i])
#      21
#
# /home/minjae/Reinforcement Learning/Strategy.pyc in run_RL(self, case_n, Exp, seed_n, Double, Dueling, Prioritized)
#     285                     if Double:
#     286                         loss, _ = Train.replay_train(mainDQN, targetDQN, minibatch, w_batch,
# --> 287                                                                      Exp, dis, input_size, output_size)
#     288                     else:
#     289                         loss, _ = Train.replay_train_unDouble(mainDQN, minibatch, w_batch,
#
# /home/minjae/Reinforcement Learning/Train.pyc in replay_train(mainDQN, targetDQN, train_batch, w_batch, Exp, dis, input_size, output_size)
#      22                 Q[0,action] = reward + dis * (targetDQN.predict(next_state)[0, action0])
#      23             else:
# ---> 24                 Q[0,action] = Exploration.Q_value(Exp, reward, dis, targetDQN.predict(next_state)[0])
#      25
#      26         y_stack = np.vstack([y_stack, Q])
#
# /home/minjae/Reinforcement Learning/Exploration.pyc in Q_value(Exp, reward, dis, action_Q)
#      80         return reward + dis * action_V
#      81     elif Exp == 'sparsemax' or Exp == 'sparse+eps':
# ---> 82         action_max = sparsemax(action_Q)
#      83         return reward + dis * action_max
#      84     else:
#
# /home/minjae/Reinforcement Learning/Exploration.pyc in sparsemax(x, scale)
#      70 def sparsemax(x,scale = 1):
#      71     x = np.array(x/scale)
# ---> 72     tau, S = sparsetau(x)
#      73     spmax_x = 0.5*(S**2 - tau**2).sum() + 0.5
#      74     spmax_x = scale*spmax_x
#
# /home/minjae/Reinforcement Learning/Exploration.pyc in sparsetau(x)
#      36     S = np.array([])
#      37     for i in range(0,len(x)):
# ---> 38         if 1+(i+1)*sorted_x[i] >= (sorted_x[0:(i+1)]).sum():
#      39             S = np.append(S,sorted_x[i])
#      40     tau = (S.sum() - 1)/S.size
#
# /usr/local/lib/python2.7/dist-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
