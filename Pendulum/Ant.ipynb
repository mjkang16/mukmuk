# %%
import tensorflow as tf
from Strategy import RL

case_num = 3

# 1 : epsilon , 2 : softmax , 3 : sparsemax
Exp_list = ['sparsemax', 'sparsemax', 'sparsemax']

action_res_list = [3, 3, 3, 3, 3, 3, 3, 3]

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
for i in range(case_num):
    tf.reset_default_graph()
    
    with tf.Session(config=config) as sess :
        
        CartPole = RL(sess, dis = 0.99, REPLAY_MEMORY = 40000, max_steps = 1500000, action_res = action_res_list,
                      
                      batch_size = 256, training_step = 1, copy_step = 4,
                      eps_div = 4000, repu_num = 1,
                      layer_size_Q1 = 400, layer_size_Q2 = 300, learning_rate_Q = 0.0001,
                      
                      alpha = 0.6, beta_init = 0.4, eps = 0.01, save_epi = 50, beta_max_step = 500000,
                      ending_cond_epis = 100, ending_cond_reward = 10000,
                      
                      Game = 'Ant-v1', file_name = 'Ant_E(3)_(256,1,4,4000,1,0.0001)',
                      Exp = 'epsilon', case_n = i+2, seed_n = i+1,
                      Double = True, Dueling = True, Prioritized = True)
    
    sess.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [2018-05-08 17:24:41,680] Making new env: Ant-v1
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2018-05-08 17:24:43,258] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# CASE 2
# ...
