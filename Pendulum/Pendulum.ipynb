# %%
import tensorflow as tf
from Strategy import RL

case_num = 3

# 1 : epsilon , 2 : softmax , 3 : sparsemax
Exp_list = ['epsilon', 'epsilon', 'epsilon']

Double_list = [True, True, True]
Dueling_list = [True, True, True]
Prioritized_list = [False, False, False]

action_res_list = 1001
l_list = [0.0001, 0.0001, 0.001]

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
for i in range(case_num):
    tf.reset_default_graph()
    
    with tf.Session(config=config) as sess :
        
        CartPole = RL(sess, dis = 0.99, REPLAY_MEMORY = 10000, max_episodes = 1000, action_res = 1001,
                      
                      batch_size = 32, training_step = 1, copy_step = 4,
                      eps_div = 4, repu_num = 1,
                      layer_size_Q1 = 128, layer_size_Q2 = 128, learning_rate_Q = 0.001,
                      
                      alpha = 0.6, beta_init = 0.4, eps = 0.01, save_epi = 10000,
                      ending_cond_epis = 100, ending_cond_reward = -200,
                      
                      Game = 'Pendulum-v0', file_name = 'Pendulum_EPS_G1_seed',
                      Exp = Exp_list[i], case_n = i+1, seed_n = i,
                      Double = Double_list[i], Dueling = Dueling_list[i], Prioritized = Prioritized_list[i])
    
    sess.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [2018-03-09 05:00:47,559] Making new env: Pendulum-v0
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2018-03-09 05:00:48,210] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# CASE 1
# ...
