# %%
import pickle
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np


def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.prop_cycler.next()
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr
    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)


############################################################################

file_name = 'HalfCheetah_DDPG_batch32_seed'

with open('/home/jolp/Desktop/Data/'+file_name+'1', 'rb') as fin1:
    step_avg_list_1 = pickle.load(fin1)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_1', 'rb') as fin2:
    global_step_list_1 = pickle.load(fin2)

with open('/home/jolp/Desktop/Data/'+file_name+'2', 'rb') as fin3:
    step_avg_list_2 = pickle.load(fin3)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_2', 'rb') as fin4:
    global_step_list_2 = pickle.load(fin4)

with open('/home/jolp/Desktop/Data/'+file_name+'3', 'rb') as fin5:
    step_avg_list_3 = pickle.load(fin5)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_3', 'rb') as fin6:
    global_step_list_3 = pickle.load(fin6)
"""
global_step_list_1 = []
global_step_list_2 = []
global_step_list_3 = []
for n in range(1, 801):
    global_step_list_1.append(1000*n)
    global_step_list_2.append(1000*n)
    global_step_list_3.append(1000*n)
"""

print_step_avg_list_1 = []
print_step_std_list_1 = []
step_num = 800000
step1 = step2 = step3 = 0
for num in range(step_num):
    if num == global_step_list_1[step1]:
        step1 += 1
    if num == global_step_list_2[step2]:
        step2 += 1
    if num == global_step_list_3[step3]:
        step3 += 1
    
    print_step_avg_list_1.append((step_avg_list_1[step1]+step_avg_list_2[step2]+step_avg_list_3[step3])/3)
    print_step_std_list_1.append(0.5*np.std([step_avg_list_1[step1], step_avg_list_2[step2], step_avg_list_3[step3]]))
    
    #step_avg_list.append((step_avg_list_1[step1]+step_avg_list_2[step2])/2)
    #step_std_list.append(np.std([step_avg_list_1[step1], step_avg_list_2[step2]]))
############################################################################    

############################################################################

file_name = 'HalfCheetah_DDPG_batch64_seed'

with open('/home/jolp/Desktop/Data/'+file_name+'1', 'rb') as fin1:
    step_avg_list_1 = pickle.load(fin1)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_1', 'rb') as fin2:
    global_step_list_1 = pickle.load(fin2)

with open('/home/jolp/Desktop/Data/'+file_name+'2', 'rb') as fin3:
    step_avg_list_2 = pickle.load(fin3)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_2', 'rb') as fin4:
    global_step_list_2 = pickle.load(fin4)

with open('/home/jolp/Desktop/Data/'+file_name+'3', 'rb') as fin5:
    step_avg_list_3 = pickle.load(fin5)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_3', 'rb') as fin6:
    global_step_list_3 = pickle.load(fin6)
"""
global_step_list_1 = []
global_step_list_2 = []
global_step_list_3 = []
for n in range(1, 801):
    global_step_list_1.append(1000*n)
    global_step_list_2.append(1000*n)
    global_step_list_3.append(1000*n)
"""

print_step_avg_list_2 = []
print_step_std_list_2 = []
step_num = 800000
step1 = step2 = step3 = 0
for num in range(step_num):
    if num == global_step_list_1[step1]:
        step1 += 1
    if num == global_step_list_2[step2]:
        step2 += 1
    if num == global_step_list_3[step3]:
        step3 += 1
    
    print_step_avg_list_2.append((step_avg_list_1[step1]+step_avg_list_2[step2]+step_avg_list_3[step3])/3)
    print_step_std_list_2.append(0.5*np.std([step_avg_list_1[step1], step_avg_list_2[step2], step_avg_list_3[step3]]))
    
############################################################################

############################################################################

file_name = 'HalfCheetah_DDPG_batch128_seed'

with open('/home/jolp/Desktop/Data/'+file_name+'1', 'rb') as fin1:
    step_avg_list_1 = pickle.load(fin1)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_1', 'rb') as fin2:
    global_step_list_1 = pickle.load(fin2)

with open('/home/jolp/Desktop/Data/'+file_name+'2', 'rb') as fin3:
    step_avg_list_2 = pickle.load(fin3)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_2', 'rb') as fin4:
    global_step_list_2 = pickle.load(fin4)

with open('/home/jolp/Desktop/Data/'+file_name+'3', 'rb') as fin5:
    step_avg_list_3 = pickle.load(fin5)

with open('/home/jolp/Desktop/Data/'+file_name+'_global_3', 'rb') as fin6:
    global_step_list_3 = pickle.load(fin6)

print_step_avg_list_3 = []
print_step_std_list_3 = []
step_num = 800000
step1 = step2 = step3 = 0
for num in range(step_num):
    if num == global_step_list_1[step1]:
        step1 += 1
    if num == global_step_list_2[step2]:
        step2 += 1
    if num == global_step_list_3[step3]:
        step3 += 1
    
    print_step_avg_list_3.append((step_avg_list_1[step1]+step_avg_list_2[step2]+step_avg_list_3[step3])/3)
    print_step_std_list_3.append(0.5*np.std([step_avg_list_1[step1], step_avg_list_2[step2], step_avg_list_3[step3]]))
    
############################################################################

x_values = list(range(1, step_num+1))
y_1_values = print_step_avg_list_1[:]
y_2_values = print_step_avg_list_2[:]
y_3_values = print_step_avg_list_3[:]

plt.plot(x_values, y_1_values, c='green')
plt.plot(x_values, y_2_values, c='red')
plt.plot(x_values, y_3_values, c='blue')

plt.errorbar(x_values, y_1_values, yerr = print_step_std_list_1, ecolor='green', alpha=0.1)
plt.errorbar(x_values, y_2_values, yerr = print_step_std_list_2, ecolor='red', alpha=0.1)
plt.errorbar(x_values, y_3_values, yerr = print_step_std_list_3, ecolor='blue', alpha=0.1)

#errorfill(x_values, y_1_values, yerr = print_step_std_list_1)

def custom_plot(x, y, yerror, **kwargs):
    ax = kwargs.pop('ax', plt.gca())
    base_line, = ax.plot(x, y, **kwargs)
    ax.errorbar(x, y, yerror, markerfacecolor=base_line.get_color(), alpha=0.1)

#custom_plot(x_values, y_1_values, print_step_std_list_1, c='green')
#custom_plot(x_values, y_2_values, print_step_std_list_2, c='red')
#custom_plot(x_values, y_3_values, print_step_std_list_3, c='blue')

plt.title('HalfCheetah, batchsize = 32, 64, 128')
plt.grid(True)
plt.show()
