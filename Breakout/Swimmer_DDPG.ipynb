# %%
import tensorflow as tf
from Strategy_DDPG import DDPG

case_num = 3

#seed_list = [0, 0, 0]

batch_list = [128, 32, 512]
Q_l_rate_list = [0.0002, 0.0005, 0.001]
A_l_rate_list = [0.0002, 0.0005, 0.001]

config = tf.ConfigProto()
config.gpu_options.allow_growth = True
for i in range(case_num):
    tf.reset_default_graph()
    with tf.Session(config=config) as sess :
        
        Swimmer = DDPG(sess, dis = 0.99, REPLAY_MEMORY = 100000, max_episodes = 2000, seed_n = i,
                      
                      batch_size = 128, tau = 0.001, save_epi = 100,
                      
                      layer_size_Q1 = 100, layer_size_Q2 = 50, learning_rate_Q = 0.0001,
                      layer_size_A1 = 100, layer_size_A2 = 50, learning_rate_A = 0.001,
                      
                      ending_cond_epis = 100, ending_cond_reward = 360,
                      Game = 'Swimmer-v1', file_name = 'Swimmer_DDPG_batch256_seed', case_n = i+1)
    sess.close()
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [2018-03-07 01:10:21,540] Making new env: Swimmer-v1
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [2018-03-07 01:10:22,191] From /usr/local/lib/python2.7/dist-packages/tensorflow/python/util/tf_should_use.py:107: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# CASE 1
# ...
